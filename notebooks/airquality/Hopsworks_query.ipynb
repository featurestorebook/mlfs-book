# %%
# Print the unique keys of the Hopsworks database

import hopsworks 
project = hopsworks.login()
fs = project.get_feature_store(name='yairrios_featurestore')
fg = fs.get_feature_group('air_quality', version=1)
# Query for distinct PK values
df = fg.select(["street"]).read().drop_duplicates()

print(df)
# Out:
# 2025-11-14 14:48:52,712 INFO: Initializing external client
# 2025-11-14 14:48:52,712 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-14 14:48:53,285 WARNING: UserWarning: The installed hopsworks client version 4.4.2 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-14 14:48:54,307 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1272002
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (4.53s)
#                                    street
# 0           San Francisco-Arkansas Street
# 4172                       hornsgatan-108
# 8346              edinburgh-salamander-st
# 10992          edinburgh-queensferry-road
# 13676  east-lothian-musselburgh-n-high-st
# 16270               edinburgh-st-leonards
# 20125               west-lothian-broxburn

# %%
df_2 = fg.read()
print(df_2.columns)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (4.44s)
# Index(['date', 'pm25', 'country', 'city', 'street', 'url'], dtype='object')

# %%
import hopsworks
import datetime

project = hopsworks.login(engine="python")
fs = project.get_feature_store()
fg = fs.get_feature_group('air_quality', version=1)

# Read the feature group into a DataFrame
df = fg.read()

# See all columns (optional)
print(df.columns)

# Get unique latitude and longitude values
latitude = df['latitude'].unique()
longitude = df['longitude'].unique()

# If you want just one value (e.g., the first one)
latitude = latitude[0]
longitude = longitude[0]

today = datetime.date.today()
# Out:
# 2025-11-14 14:50:45,605 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2025-11-14 14:50:45,637 INFO: Initializing external client
# 2025-11-14 14:50:45,637 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-14 14:50:46,145 WARNING: UserWarning: The installed hopsworks client version 4.4.2 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-14 14:50:46,883 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1272002
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.85s)
# Index(['date', 'pm25', 'country', 'city', 'street', 'url'], dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/ScalableLab1/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 15
#      12 print(df.columns)
#      14 # Get unique latitude and longitude values
# ---> 15 latitude = df['latitude'].unique()
#      16 longitude = df['longitude'].unique()
#      18 # If you want just one value (e.g., the first one)
#
# File /opt/anaconda3/envs/ScalableLab1/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/anaconda3/envs/ScalableLab1/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'latitude'
