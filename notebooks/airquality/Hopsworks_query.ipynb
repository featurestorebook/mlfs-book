# %%
# Print the unique keys of the Hopsworks database

import hopsworks 
project = hopsworks.login()
fs = project.get_feature_store(name='yairrios_featurestore')
fg = fs.get_feature_group('air_quality', version=1)
# Query for distinct PK values
df = fg.select(["street"]).read().drop_duplicates()

print(df)
# Out:
# 2025-11-13 14:19:52,423 INFO: Initializing external client
# 2025-11-13 14:19:52,424 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-13 14:19:52,967 WARNING: UserWarning: The installed hopsworks client version 4.4.2 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# 2025-11-13 14:19:53,875 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1272002
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.64s)
#                                    street
# 0           San Francisco-Arkansas Street
# 4172                       hornsgatan-108
# 8346              edinburgh-salamander-st
# 10992          edinburgh-queensferry-road
# 13676  east-lothian-musselburgh-n-high-st
# 16270               edinburgh-st-leonards
# 20125               west-lothian-broxburn
