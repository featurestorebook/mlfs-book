# %% [markdown]
# # Part 01: Feature Backfill for **all sensors of the city**

# %%
import sys
from pathlib import Path
import warnings
warnings.filterwarnings("ignore", module="IPython")

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir)
    print("Local environment")

print(f"Root dir: {root_dir}")

# Add the root directory to the `PYTHONPATH`
if root_dir not in sys.path:
    sys.path.append(root_dir)
    print(f"Added the following directory to the PYTHONPATH: {root_dir}")

# Set the environment variables from the file <root_dir>/.env
from mlfs import config
settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Root dir: /Users/appbites/Desktop/mlfs-book
# HopsworksSettings initialized!

# %% [markdown]
# ## Imports

# %%
import datetime
import requests
import pandas as pd
import hopsworks
from mlfs.airquality import util
import datetime
from pathlib import Path
import json
import re
import os
import warnings
warnings.filterwarnings("ignore")

# %%
project = hopsworks.login(engine="python")
# Out:
# 2025-11-18 13:02:23,559 INFO: Initializing external client
# 2025-11-18 13:02:23,559 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-18 13:02:25,235 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1289364

# %%
# taken from ~/.env. You can also replace settings.AQICN_API_KEY with the api key value as a string "...."
if settings.AQICN_API_KEY is None:
    print("You need to set AQICN_API_KEY either in this cell or in ~/.env")
    sys.exit(1)

AQICN_API_KEY = settings.AQICN_API_KEY.get_secret_value()
aqicn_url = settings.AQICN_URL
country = settings.AQICN_COUNTRY
city = settings.AQICN_CITY
street = settings.AQICN_STREET
latitude, longitude = util.get_city_coordinates(city)
secrets = hopsworks.get_secrets_api()

# Replace any existing secret with the new value
secret = secrets.get_secret("AQICN_API_KEY")
if secret is not None:
    secret.delete()
    print("Replacing existing AQICN_API_KEY")

secrets.create_secret("AQICN_API_KEY", AQICN_API_KEY)
# Out:
# Replacing existing AQICN_API_KEY
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Secret('AQICN_API_KEY', 'PRIVATE')

# %% [markdown]
# ### Validate the AQICN_API_KEY

# %%
today = datetime.date.today()
try:
    aq_today_df = util.get_pm25(aqicn_url, country, city, street, today, AQICN_API_KEY)
except hopsworks.RestAPIError:
    print("It looks like the AQICN_API_KEY doesn't work for your sensor. Is the API key correct? Is the sensor URL correct?")

aq_today_df.head()
# Out:
#    pm25  country    city                          street       date  \
# 0  21.0  austria  vienna  ecke-taborstrasse-glockengasse 2025-11-18
#
#                                  url
# 0  https://api.waqi.info/feed/@2860/

# %% [markdown]
# ### Find all sensors of the city

# %%
# --- Step 1: Search for stations in the city ---

# Approx Vienna bounding box
south, west, north, east = 48.08, 16.18, 48.33, 16.58

bounds_url = "https://api.waqi.info/map/bounds/"
params = {"token": AQICN_API_KEY, "latlng": f"{south},{west},{north},{east}"}
r = requests.get(bounds_url, params=params, timeout=20)
r.raise_for_status()
stations_geo = r.json().get("data", []) or []

keyword = f"{city}"
search_url = "https://api.waqi.info/search/"
search_params = {"token": AQICN_API_KEY, "keyword": keyword}

search_resp = requests.get(search_url, params=search_params, timeout=15)
search_resp.raise_for_status()
search_data = search_resp.json()

stations = search_data.get("data", [])
print(f"Found {len(stations)} stations matching '{keyword}'")

# --- Step 2: Convert to Pandas DataFrame ---
records = []
for s in stations:
    station = s.get("station", {})
    records.append({
        "uid": s.get("uid"),
        "name": station.get("name"),
        "country": station.get("country"),
        "lat": station.get("geo", [None, None])[0],
        "lon": station.get("geo", [None, None])[1],
        "aqi": s.get("aqi"),
        "url": f"https://aqicn.org/city/{station.get('url')}"
    })

df = pd.DataFrame(records)

# --- Step 3: Display ---
display(df.style.set_caption(f"WAQI stations found for {city}"))
# df.to_csv(f"../../data/list_stations_{city}.csv", index=False)
# print(f"Saved results to waqi_stations_{city}.csv")
# Out:
# Found 14 stations matching 'vienna'
# <style type="text/css">
# </style>
# <table id="T_f3e84">
#   <caption>WAQI stations found for vienna</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3e84_level0_col0" class="col_heading level0 col0" >uid</th>
#       <th id="T_f3e84_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_f3e84_level0_col2" class="col_heading level0 col2" >country</th>
#       <th id="T_f3e84_level0_col3" class="col_heading level0 col3" >lat</th>
#       <th id="T_f3e84_level0_col4" class="col_heading level0 col4" >lon</th>
#       <th id="T_f3e84_level0_col5" class="col_heading level0 col5" >aqi</th>
#       <th id="T_f3e84_level0_col6" class="col_heading level0 col6" >url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3e84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3e84_row0_col0" class="data row0 col0" >2860</td>
#       <td id="T_f3e84_row0_col1" class="data row0 col1" >Ecke Taborstraße - Glockengasse, Austria</td>
#       <td id="T_f3e84_row0_col2" class="data row0 col2" >AT</td>
#       <td id="T_f3e84_row0_col3" class="data row0 col3" >48.216739</td>
#       <td id="T_f3e84_row0_col4" class="data row0 col4" >16.380918</td>
#       <td id="T_f3e84_row0_col5" class="data row0 col5" >21</td>
#       <td id="T_f3e84_row0_col6" class="data row0 col6" >https://aqicn.org/city/austria/ecke-taborstrasse-glockengasse</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3e84_row1_col0" class="data row1 col0" >2855</td>
#       <td id="T_f3e84_row1_col1" class="data row1 col1" >1, Hausgrundweg 23, Gstr. 254, Austria</td>
#       <td id="T_f3e84_row1_col2" class="data row1 col2" >AT</td>
#       <td id="T_f3e84_row1_col3" class="data row1 col3" >48.226361</td>
#       <td id="T_f3e84_row1_col4" class="data row1 col4" >16.458345</td>
#       <td id="T_f3e84_row1_col5" class="data row1 col5" >17</td>
#       <td id="T_f3e84_row1_col6" class="data row1 col6" >https://aqicn.org/city/austria/hausgrundweg-23--gstr.-254/1</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3e84_row2_col0" class="data row2 col0" >4736</td>
#       <td id="T_f3e84_row2_col1" class="data row2 col1" >250, Wehlistraße 366, Gstr.Nr.2157, Austria</td>
#       <td id="T_f3e84_row2_col2" class="data row2 col2" >AT</td>
#       <td id="T_f3e84_row2_col3" class="data row2 col3" >48.203060</td>
#       <td id="T_f3e84_row2_col4" class="data row2 col4" >16.434550</td>
#       <td id="T_f3e84_row2_col5" class="data row2 col5" >13</td>
#       <td id="T_f3e84_row2_col6" class="data row2 col6" >https://aqicn.org/city/austria/wehlistrasse-366--gstr.nr.2157/250</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3e84_row3_col0" class="data row3 col0" >2857</td>
#       <td id="T_f3e84_row3_col1" class="data row3 col1" >Umspannwerk Gaudenzdorfer Gürtel, Austria</td>
#       <td id="T_f3e84_row3_col2" class="data row3 col2" >AT</td>
#       <td id="T_f3e84_row3_col3" class="data row3 col3" >48.187147</td>
#       <td id="T_f3e84_row3_col4" class="data row3 col4" >16.339331</td>
#       <td id="T_f3e84_row3_col5" class="data row3 col5" >13</td>
#       <td id="T_f3e84_row3_col6" class="data row3 col6" >https://aqicn.org/city/austria/umspannwerk-gaudenzdorfer-gurtel</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3e84_row4_col0" class="data row4 col0" >4738</td>
#       <td id="T_f3e84_row4_col1" class="data row4 col1" >Floridsdorf, Gerichtsgasse 1a (Prager Str. 65m), Austria</td>
#       <td id="T_f3e84_row4_col2" class="data row4 col2" >AT</td>
#       <td id="T_f3e84_row4_col3" class="data row4 col3" >48.261086</td>
#       <td id="T_f3e84_row4_col4" class="data row4 col4" >16.396954</td>
#       <td id="T_f3e84_row4_col5" class="data row4 col5" >13</td>
#       <td id="T_f3e84_row4_col6" class="data row4 col6" >https://aqicn.org/city/austria/floridsdorf--gerichtsgasse-1a-prager-str.-65m</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3e84_row5_col0" class="data row5 col0" >2870</td>
#       <td id="T_f3e84_row5_col1" class="data row5 col1" >252, Belgradplatz (Südostecke), Gstr.Nr. 816, Austria</td>
#       <td id="T_f3e84_row5_col2" class="data row5 col2" >AT</td>
#       <td id="T_f3e84_row5_col3" class="data row5 col3" >48.174353</td>
#       <td id="T_f3e84_row5_col4" class="data row5 col4" >16.361417</td>
#       <td id="T_f3e84_row5_col5" class="data row5 col5" >13</td>
#       <td id="T_f3e84_row5_col6" class="data row5 col6" >https://aqicn.org/city/austria/belgradplatz-sudostecke--gstr.nr.-816/252</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3e84_row6_col0" class="data row6 col0" >14537</td>
#       <td id="T_f3e84_row6_col1" class="data row6 col1" >Allgemeines Krankenhaus, Ostringweg (zwischen Gebäuden BT25), Austria</td>
#       <td id="T_f3e84_row6_col2" class="data row6 col2" >AT</td>
#       <td id="T_f3e84_row6_col3" class="data row6 col3" >48.219110</td>
#       <td id="T_f3e84_row6_col4" class="data row6 col4" >16.349818</td>
#       <td id="T_f3e84_row6_col5" class="data row6 col5" >13</td>
#       <td id="T_f3e84_row6_col6" class="data row6 col6" >https://aqicn.org/city/austria/allgemeines-krankenhaus--ostringweg-zwischen-gebauden-bt25</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f3e84_row7_col0" class="data row7 col0" >4739</td>
#       <td id="T_f3e84_row7_col1" class="data row7 col1" >4, Schafbergbad, Josef Redl Gasse 2, Gstr.Nr. 698, Austria</td>
#       <td id="T_f3e84_row7_col2" class="data row7 col2" >AT</td>
#       <td id="T_f3e84_row7_col3" class="data row7 col3" >48.235370</td>
#       <td id="T_f3e84_row7_col4" class="data row7 col4" >16.301563</td>
#       <td id="T_f3e84_row7_col5" class="data row7 col5" >3</td>
#       <td id="T_f3e84_row7_col6" class="data row7 col6" >https://aqicn.org/city/austria/schafbergbad--josef-redl-gasse-2--gstr.nr.-698/4</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f3e84_row8_col0" class="data row8 col0" >2850</td>
#       <td id="T_f3e84_row8_col1" class="data row8 col1" >Kendlerstraße 40 (Umspannwerk), Austria</td>
#       <td id="T_f3e84_row8_col2" class="data row8 col2" >AT</td>
#       <td id="T_f3e84_row8_col3" class="data row8 col3" >48.205000</td>
#       <td id="T_f3e84_row8_col4" class="data row8 col4" >16.309750</td>
#       <td id="T_f3e84_row8_col5" class="data row8 col5" >-</td>
#       <td id="T_f3e84_row8_col6" class="data row8 col6" >https://aqicn.org/city/austria/kendlerstrasse-40-umspannwerk</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f3e84_row9_col0" class="data row9 col0" >2813</td>
#       <td id="T_f3e84_row9_col1" class="data row9 col1" >Laaer Berg, Theodor Sickel-Gasse 1, Austria</td>
#       <td id="T_f3e84_row9_col2" class="data row9 col2" >AT</td>
#       <td id="T_f3e84_row9_col3" class="data row9 col3" >48.161036</td>
#       <td id="T_f3e84_row9_col4" class="data row9 col4" >16.392920</td>
#       <td id="T_f3e84_row9_col5" class="data row9 col5" >-</td>
#       <td id="T_f3e84_row9_col6" class="data row9 col6" >https://aqicn.org/city/austria/laaer-berg--theodor-sickel-gasse-1</td>
#     </tr>
#     <tr>
#       <th id="T_f3e84_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f3e84_row10_col0" class="data row10 col0" >2848</td>
#       <td id="T_f3e84_row10_col1" class="data row10 col1" >Allgemeines Krankenhaus, Südringweg, Austria</td>
#       <td id="T_f3e84_row10_col2" class="data row10 col2" >AT</td>
#       <td id="T_f3e84_row10_col3" class="data row10 col3" >48.219517</td>
#       <td id="T_f3e84_row10_col4" class="data row10 col4" >16.345552</td>

# %% [markdown]
# ### Filter the stations that report PM2.5

# %%
# --- Step 2: Check which stations report PM2.5 ---
stations_with_pm25 = []

for item in stations:
    uid = item["uid"]
    name = item["station"]["name"]
    geo = item["station"]["geo"]

    feed_url = f"https://api.waqi.info/feed/@{uid}/"
    feed_resp = requests.get(feed_url, params={"token": AQICN_API_KEY}, timeout=15)
    feed_resp.raise_for_status()
    feed_data = feed_resp.json().get("data", {})
    iaqi = feed_data.get("iaqi", {}) or {}

    if "pm25" in iaqi:
        stations_with_pm25.append({
            "uid": uid,
            "name": name,
            "latitude": geo[0],
            "longitude": geo[1],
            "AQI": feed_data.get("aqi"),
            "PM2.5": iaqi["pm25"].get("v") if isinstance(iaqi["pm25"], dict) else iaqi["pm25"],
            "URL": f"https://aqicn.org/city/@{uid}"
        })

df = pd.DataFrame(stations_with_pm25)
display(df.style.set_caption(f"PM2.5 Stations in {city}, {country}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_cba53">
#   <caption>PM2.5 Stations in vienna, austria</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cba53_level0_col0" class="col_heading level0 col0" >uid</th>
#       <th id="T_cba53_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_cba53_level0_col2" class="col_heading level0 col2" >latitude</th>
#       <th id="T_cba53_level0_col3" class="col_heading level0 col3" >longitude</th>
#       <th id="T_cba53_level0_col4" class="col_heading level0 col4" >AQI</th>
#       <th id="T_cba53_level0_col5" class="col_heading level0 col5" >PM2.5</th>
#       <th id="T_cba53_level0_col6" class="col_heading level0 col6" >URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cba53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cba53_row0_col0" class="data row0 col0" >2860</td>
#       <td id="T_cba53_row0_col1" class="data row0 col1" >Ecke Taborstraße - Glockengasse, Austria</td>
#       <td id="T_cba53_row0_col2" class="data row0 col2" >48.216739</td>
#       <td id="T_cba53_row0_col3" class="data row0 col3" >16.380918</td>
#       <td id="T_cba53_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_cba53_row0_col5" class="data row0 col5" >21</td>
#       <td id="T_cba53_row0_col6" class="data row0 col6" >https://aqicn.org/city/@2860</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cba53_row1_col0" class="data row1 col0" >2855</td>
#       <td id="T_cba53_row1_col1" class="data row1 col1" >1, Hausgrundweg 23, Gstr. 254, Austria</td>
#       <td id="T_cba53_row1_col2" class="data row1 col2" >48.226361</td>
#       <td id="T_cba53_row1_col3" class="data row1 col3" >16.458345</td>
#       <td id="T_cba53_row1_col4" class="data row1 col4" >17</td>
#       <td id="T_cba53_row1_col5" class="data row1 col5" >17</td>
#       <td id="T_cba53_row1_col6" class="data row1 col6" >https://aqicn.org/city/@2855</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cba53_row2_col0" class="data row2 col0" >4736</td>
#       <td id="T_cba53_row2_col1" class="data row2 col1" >250, Wehlistraße 366, Gstr.Nr.2157, Austria</td>
#       <td id="T_cba53_row2_col2" class="data row2 col2" >48.203060</td>
#       <td id="T_cba53_row2_col3" class="data row2 col3" >16.434550</td>
#       <td id="T_cba53_row2_col4" class="data row2 col4" >13</td>
#       <td id="T_cba53_row2_col5" class="data row2 col5" >13</td>
#       <td id="T_cba53_row2_col6" class="data row2 col6" >https://aqicn.org/city/@4736</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cba53_row3_col0" class="data row3 col0" >2857</td>
#       <td id="T_cba53_row3_col1" class="data row3 col1" >Umspannwerk Gaudenzdorfer Gürtel, Austria</td>
#       <td id="T_cba53_row3_col2" class="data row3 col2" >48.187147</td>
#       <td id="T_cba53_row3_col3" class="data row3 col3" >16.339331</td>
#       <td id="T_cba53_row3_col4" class="data row3 col4" >13</td>
#       <td id="T_cba53_row3_col5" class="data row3 col5" >13</td>
#       <td id="T_cba53_row3_col6" class="data row3 col6" >https://aqicn.org/city/@2857</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cba53_row4_col0" class="data row4 col0" >4738</td>
#       <td id="T_cba53_row4_col1" class="data row4 col1" >Floridsdorf, Gerichtsgasse 1a (Prager Str. 65m), Austria</td>
#       <td id="T_cba53_row4_col2" class="data row4 col2" >48.261086</td>
#       <td id="T_cba53_row4_col3" class="data row4 col3" >16.396954</td>
#       <td id="T_cba53_row4_col4" class="data row4 col4" >13</td>
#       <td id="T_cba53_row4_col5" class="data row4 col5" >13</td>
#       <td id="T_cba53_row4_col6" class="data row4 col6" >https://aqicn.org/city/@4738</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cba53_row5_col0" class="data row5 col0" >2870</td>
#       <td id="T_cba53_row5_col1" class="data row5 col1" >252, Belgradplatz (Südostecke), Gstr.Nr. 816, Austria</td>
#       <td id="T_cba53_row5_col2" class="data row5 col2" >48.174353</td>
#       <td id="T_cba53_row5_col3" class="data row5 col3" >16.361417</td>
#       <td id="T_cba53_row5_col4" class="data row5 col4" >13</td>
#       <td id="T_cba53_row5_col5" class="data row5 col5" >13</td>
#       <td id="T_cba53_row5_col6" class="data row5 col6" >https://aqicn.org/city/@2870</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cba53_row6_col0" class="data row6 col0" >14537</td>
#       <td id="T_cba53_row6_col1" class="data row6 col1" >Allgemeines Krankenhaus, Ostringweg (zwischen Gebäuden BT25), Austria</td>
#       <td id="T_cba53_row6_col2" class="data row6 col2" >48.219110</td>
#       <td id="T_cba53_row6_col3" class="data row6 col3" >16.349818</td>
#       <td id="T_cba53_row6_col4" class="data row6 col4" >13</td>
#       <td id="T_cba53_row6_col5" class="data row6 col5" >13</td>
#       <td id="T_cba53_row6_col6" class="data row6 col6" >https://aqicn.org/city/@14537</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cba53_row7_col0" class="data row7 col0" >4739</td>
#       <td id="T_cba53_row7_col1" class="data row7 col1" >4, Schafbergbad, Josef Redl Gasse 2, Gstr.Nr. 698, Austria</td>
#       <td id="T_cba53_row7_col2" class="data row7 col2" >48.235370</td>
#       <td id="T_cba53_row7_col3" class="data row7 col3" >16.301563</td>
#       <td id="T_cba53_row7_col4" class="data row7 col4" >3</td>
#       <td id="T_cba53_row7_col5" class="data row7 col5" >13</td>
#       <td id="T_cba53_row7_col6" class="data row7 col6" >https://aqicn.org/city/@4739</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cba53_row8_col0" class="data row8 col0" >2850</td>
#       <td id="T_cba53_row8_col1" class="data row8 col1" >Kendlerstraße 40 (Umspannwerk), Austria</td>
#       <td id="T_cba53_row8_col2" class="data row8 col2" >48.205000</td>
#       <td id="T_cba53_row8_col3" class="data row8 col3" >16.309750</td>
#       <td id="T_cba53_row8_col4" class="data row8 col4" >-</td>
#       <td id="T_cba53_row8_col5" class="data row8 col5" >17</td>
#       <td id="T_cba53_row8_col6" class="data row8 col6" >https://aqicn.org/city/@2850</td>
#     </tr>
#     <tr>
#       <th id="T_cba53_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cba53_row9_col0" class="data row9 col0" >2813</td>
#       <td id="T_cba53_row9_col1" class="data row9 col1" >Laaer Berg, Theodor Sickel-Gasse 1, Austria</td>
#       <td id="T_cba53_row9_col2" class="data row9 col2" >48.161036</td>
#       <td id="T_cba53_row9_col3" class="data row9 col3" >16.392920</td>
#       <td id="T_cba53_row9_col4" class="data row9 col4" >89</td>
#       <td id="T_cba53_row9_col5" class="data row9 col5" >89</td>
#       <td id="T_cba53_row9_col6" class="data row9 col6" >https://aqicn.org/city/@2813</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Prepare the stations data to be stored in the Feature Group

# %%
# Get the street names from the stations.json in order to insert that info in the Feature Group table
stations_path = Path(f"{root_dir}/stations.json")

with open(stations_path, "r") as f:
    stations_meta = json.load(f)

print(f"Loaded {len(stations_meta)} stations.")
for s in stations_meta:
    print(f"{s['uid']}: {s['name']} — {s['street']}")

# Convert list -> dict for quick lookup by UID
station_meta_dict = {s["uid"]: s for s in stations_meta}


# Directory with all historical CSVs
data_dir = Path(f"{root_dir}/data")

print("Looking for CSV files in:", data_dir.resolve())

# Empty list to collect data from each station
all_stations_data = []

# Loop over every CSV in the folder
for csv_file in data_dir.glob("vienna_station_*.csv"):
    # Extract the station UID from the filename (e.g. vienna_station_4738_floridsdorf.csv)
    try:
        station_uid = int(csv_file.stem.split("_")[2])
    except (IndexError, ValueError):
        print(f" Could not parse UID from {csv_file.name}, skipping.")
        continue

    # STEP 5: Read CSV
    df = pd.read_csv(csv_file, parse_dates=['date'], skipinitialspace=True)

    # STEP 6: Keep only relevant columns
    if 'pm25' in df.columns:
        df_aq = df[['date', 'pm25']].copy()
    elif 'pm2.5' in df.columns:
        df_aq = df[['date', 'pm2.5']].rename(columns={'pm2.5': 'pm25'})
    else:
        print(f" No PM2.5 column found in {csv_file.name}, skipping.")
        continue

    
    # STEP 7: Drop missing data
    df_aq.dropna(subset=['pm25'], inplace=True)
    df_aq['pm25'] = df_aq['pm25'].astype('float32')

    # STEP 8: Add metadata columns
    meta = station_meta_dict.get(station_uid, {})
    df_aq['country'] = country
    df_aq['city'] = city
    df_aq["street"] = meta.get("street", "Unknown")
    df_aq['station_uid'] = station_uid
    df_aq['source_file'] = csv_file.name

     # STEP 9: Create lag features: pm25 one, two and three days before
    df_aq_sorted = df_aq.sort_values(["station_uid", "date"])
    for prev_day in (1, 2, 3):
        df_aq_sorted[f"pm25_t{prev_day}"] = (df_aq_sorted.groupby("station_uid")["pm25"].shift(prev_day))
    
    df_aq_sorted = df_aq_sorted.dropna(subset=["pm25_t1", "pm25_t2", "pm25_t3"])  # Drop the first 3 rows of each station (they don't have full history)
    df_aq = df_aq_sorted
    
    # Sdd the AQICN station URL
    df_aq['url'] = f"https://aqicn.org/station/@{station_uid}/"

    # Append to master list
    all_stations_data.append(df_aq)

# Combine all into a single DataFrame
df_all = pd.concat(all_stations_data, ignore_index=True)

print(f" Combined data from {len(all_stations_data)} stations ({len(df_all)} total rows).")
df_all.head()
# Out:
# Loaded 9 stations.
# 4738: Floridsdorf — Floridsdorf, Gerichtsgasse 1a (Prager Str. 65m)
# 4739: Schafbergbad — Schafbergbad, Josef Redl Gasse 2, Gstr.Nr. 698
# 4736: Wehlistraße — Wehlistraße 366, Gstr.Nr.2157
# 14537: Allgemeines Krankenhaus (AKH) — Ostringweg (zwischen Gebäuden BT25)
# 2855: Hausgrundweg — Hausgrundweg 23, Gstr. 254
# 2857: Gaudenzdorfer Gürtel — Umspannwerk Gaudenzdorfer Gürtel
# 2850: Kendlerstraße — Kendlerstraße 40 (Umspannwerk)
# 2870: Belgradplatz — Belgradplatz (Südostecke), Gstr.Nr. 816
# 2860: Taborstraße — Ecke Taborstraße - Glockengasse
# Looking for CSV files in: /Users/appbites/Desktop/mlfs-book/data
#  Combined data from 9 stations (27646 total rows).
#         date  pm25  country    city                          street  \
# 0 2014-01-04  89.0  austria  vienna  Kendlerstraße 40 (Umspannwerk)
# 1 2014-01-05  47.0  austria  vienna  Kendlerstraße 40 (Umspannwerk)
# 2 2014-01-06  43.0  austria  vienna  Kendlerstraße 40 (Umspannwerk)
# 3 2014-01-07  74.0  austria  vienna  Kendlerstraße 40 (Umspannwerk)
# 4 2014-01-08  68.0  austria  vienna  Kendlerstraße 40 (Umspannwerk)
#
#    station_uid                             source_file  pm25_t1  pm25_t2  \
# 0         2850  vienna_station_2850_kendlerstrasse.csv     99.0     76.0
# 1         2850  vienna_station_2850_kendlerstrasse.csv     89.0     99.0
# 2         2850  vienna_station_2850_kendlerstrasse.csv     47.0     89.0
# 3         2850  vienna_station_2850_kendlerstrasse.csv     43.0     47.0
# 4         2850  vienna_station_2850_kendlerstrasse.csv     74.0     43.0
#
#    pm25_t3                               url
# 0    105.0  https://aqicn.org/station/@2850/
# 1     76.0  https://aqicn.org/station/@2850/
# 2     99.0  https://aqicn.org/station/@2850/
# 3     89.0  https://aqicn.org/station/@2850/
# 4     47.0  https://aqicn.org/station/@2850/

# %%
today = datetime.date.today()

earliest_aq_date = pd.Series.min(df_aq['date'])
earliest_aq_date = earliest_aq_date.strftime('%Y-%m-%d')
earliest_aq_date

weather_df = util.get_historical_weather(city, earliest_aq_date, str(today), latitude, longitude)
# Out:
# Coordinates 48.18980407714844°N 16.377296447753906°E
# Elevation 194.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2509 entries, 0 to 2508
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         2509 non-null   datetime64[ns]
#  1   temperature_2m_mean          2509 non-null   float32
#  2   precipitation_sum            2509 non-null   float32
#  3   wind_speed_10m_max           2509 non-null   float32
#  4   wind_direction_10m_dominant  2509 non-null   float32
#  5   city                         2509 non-null   object
# dtypes: datetime64[ns](1), float32(4), object(1)
# memory usage: 78.5+ KB

# %% [markdown]
# ### Define Data Validation Rules

# %%
import great_expectations as ge
aq_expectation_suite = ge.core.ExpectationSuite(
    expectation_suite_name="aq_expectation_suite"
)

aq_expectation_suite.add_expectation(
    ge.core.ExpectationConfiguration(
        expectation_type="expect_column_min_to_be_between",
        kwargs={
            "column":"pm25",
            "min_value":-0.1,
            "max_value":500.0,
            "strict_min":True
        }
    )
)
# Out:
# {"expectation_type": "expect_column_min_to_be_between", "kwargs": {"column": "pm25", "min_value": -0.1, "max_value": 500.0, "strict_min": true}, "meta": {}}

# %% [markdown]
# ## Expectations for Weather Data
# Here, we define an expectation for 2 columns in our weather DataFrame - `precipitation_sum` and `wind_speed_10m_max`, where we expect both values to be greater than zero, but less than 1000.

# %%
import great_expectations as ge
weather_expectation_suite = ge.core.ExpectationSuite(
    expectation_suite_name="weather_expectation_suite"
)

def expect_greater_than_zero(col):
    weather_expectation_suite.add_expectation(
        ge.core.ExpectationConfiguration(
            expectation_type="expect_column_min_to_be_between",
            kwargs={
                "column":col,
                "min_value":-0.1,
                "max_value":1000.0,
                "strict_min":True
            }
        )
    )
expect_greater_than_zero("precipitation_sum")
expect_greater_than_zero("wind_speed_10m_max")

# %% [markdown]
# ### <span style="color:#ff5f27;"> 🔮 Connect to Hopsworks and save the sensors</span>

# %%
fs = project.get_feature_store()

# %% [markdown]
# #### Save country, city, street names as a secret

# %%
for s in stations_meta:
    uid = s["uid"]
    country = s["country"]
    city = s["city"]
    street = s["street"]
    url = s["url"]
    lat = s["lat"]
    lon = s["lon"]

    # Normalize the street name for the secret name
    safe_street = re.sub(r"[^a-zA-Z0-9]", "-", street.lower()).strip("-")

    # Build the secret name and payload
    secret_name = f"SENSOR_LOCATION_JSON_{safe_street}"
    dict_obj = {
        "station_uid": uid,
        "country": country,
        "city": city,
        "street": street,
        "url": url,
        "latitude": str(lat),
        "longitude": str(lon),
    }
    str_dict = json.dumps(dict_obj)

    # Replace existing secret if it already exists
    try:
        existing = secrets.get_secret(secret_name)
        if existing is not None:
            existing.delete()
            print(f"Replacing existing secret: {secret_name}")
    except Exception:
        pass  # Secret does not exist yet

    # Create the new secret
    secrets.create_secret(secret_name, str_dict)
    print(f"Created secret: {secret_name}")
# Out:
# Replacing existing secret: SENSOR_LOCATION_JSON_floridsdorf--gerichtsgasse-1a--prager-str--65m
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_floridsdorf--gerichtsgasse-1a--prager-str--65m
# Replacing existing secret: SENSOR_LOCATION_JSON_schafbergbad--josef-redl-gasse-2--gstr-nr--698
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_schafbergbad--josef-redl-gasse-2--gstr-nr--698
# Replacing existing secret: SENSOR_LOCATION_JSON_wehlistra-e-366--gstr-nr-2157
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_wehlistra-e-366--gstr-nr-2157
# Replacing existing secret: SENSOR_LOCATION_JSON_ostringweg--zwischen-geb-uden-bt25
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_ostringweg--zwischen-geb-uden-bt25
# Replacing existing secret: SENSOR_LOCATION_JSON_hausgrundweg-23--gstr--254
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_hausgrundweg-23--gstr--254
# Replacing existing secret: SENSOR_LOCATION_JSON_umspannwerk-gaudenzdorfer-g-rtel
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_umspannwerk-gaudenzdorfer-g-rtel
# Replacing existing secret: SENSOR_LOCATION_JSON_kendlerstra-e-40--umspannwerk
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_kendlerstra-e-40--umspannwerk
# Replacing existing secret: SENSOR_LOCATION_JSON_belgradplatz--s-dostecke---gstr-nr--816
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_belgradplatz--s-dostecke---gstr-nr--816
# Replacing existing secret: SENSOR_LOCATION_JSON_ecke-taborstra-e---glockengasse
# Secret created successfully, explore it at https://c.app.hopsworks.ai:443/account/secrets
# Created secret: SENSOR_LOCATION_JSON_ecke-taborstra-e---glockengasse

# %% [markdown]
# ### Create (or get) the shared Feature Group for Air Quality

# %%
aq_fg = fs.get_or_create_feature_group(
    name="stations_air_quality_daily",
    version=1,
    primary_key=["station_uid", "date"],
    event_time="date",
    # description="Daily PM2.5 per station for Vienna,
    description="Daily PM2.5 per station for Vienna with previous 1,2 and 3 days",
    online_enabled=False,
)

# %%
df_all["date"] = pd.to_datetime(df_all["date"]).dt.normalize()

# %%
df_to_insert = df_all[["station_uid", "date", "pm25", "pm25_t1", "pm25_t2", "pm25_t3", "country", "city", "street", "url"]]

# %%
print(f"Inserting {len(df_to_insert)} rows into stations_air_quality_daily ...")
aq_fg.insert(df_to_insert, write_options={"wait_for_job": True})
print("Air quality data successfully inserted into Hopsworks!")
# Out:
# Inserting 27646 rows into stations_air_quality_daily ...
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1289364/fs/1278019/fg/1718973
# Uploading Dataframe: 100.00% |██████████| Rows 27646/27646 | Elapsed Time: 00:02 | Remaining Time: 00:00
# Launching job: stations_air_quality_daily_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1289364/jobs/named/stations_air_quality_daily_1_offline_fg_materialization/executions
# 2025-11-18 13:03:57,006 INFO: Waiting for execution to finish. Current state: INITIALIZING. Final status: UNDEFINED
# 2025-11-18 13:04:00,194 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-11-18 13:05:55,020 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2025-11-18 13:05:55,197 INFO: Waiting for log aggregation to finish.
# 2025-11-18 13:06:07,304 INFO: Execution finished successfully.
# Air quality data successfully inserted into Hopsworks!

# %% [markdown]
# ### Enter a description for each Feature in the Feature Group

# %%
aq_fg.update_feature_description("date", "Date of measurement of air quality")
aq_fg.update_feature_description("country", "Country where the air quality was measured (sometimes a city in acqcn.org)")
aq_fg.update_feature_description("city", "City where the air quality was measured")
aq_fg.update_feature_description("street", "Street in the city where the air quality was measured")
aq_fg.update_feature_description("pm25", "Particles less than 2.5 micrometers in diameter (fine particles) pose health risk")
aq_fg.update_feature_description("pm25_t1", "pm value from previous day")
aq_fg.update_feature_description("pm25_t2", "pm value from 2 days ago")
aq_fg.update_feature_description("pm25_t3", "pm value from 3 days ago")
aq_fg.update_feature_description("station_uid", "ID of the station")
aq_fg.update_feature_description("url", "Station url")

# %% [markdown]
# ### Weather Data

# %%
# Get or create feature group
weather_fg = fs.get_or_create_feature_group(
    name='weather',
    description='Weather characteristics of each day',
    version=1,
    primary_key=['city'],
    event_time="date",
    expectation_suite=weather_expectation_suite
)

# %% [markdown]
# #### Insert the DataFrame into the Feature Group

# %%
# Insert data
weather_fg.insert(weather_df, wait=True)
# Out:
# 2025-11-18 13:13:34,536 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1289364/fs/1278019/fg/1680714
# Uploading Dataframe: 100.00% |██████████| Rows 2509/2509 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: weather_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1289364/jobs/named/weather_1_offline_fg_materialization/executions
# 2025-11-18 13:13:52,017 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-11-18 13:13:55,238 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-11-18 13:16:04,304 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2025-11-18 13:16:04,470 INFO: Waiting for log aggregation to finish.
# 2025-11-18 13:16:13,118 INFO: Execution finished successfully.
# (Job('weather_1_offline_fg_materialization', 'SPARK'),
#  {
#    "success": true,
#    "results": [
#      {
#        "success": true,
#        "expectation_config": {
#          "expectation_type": "expect_column_min_to_be_between",
#          "kwargs": {
#            "column": "wind_speed_10m_max",
#            "min_value": -0.1,
#            "max_value": 1000.0,
#            "strict_min": true
#          },
#          "meta": {
#            "expectationId": 741378
#          }
#        },
#        "result": {
#          "observed_value": 4.752135753631592,
#          "element_count": 2509,
#          "missing_count": null,
#          "missing_percent": null
#        },
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2025-11-18T12:13:34.000536Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      },
#      {
#        "success": true,
#        "expectation_config": {
#          "expectation_type": "expect_column_min_to_be_between",
#          "kwargs": {
#            "column": "precipitation_sum",
#            "min_value": -0.1,
#            "max_value": 1000.0,
#            "strict_min": true
#          },
#          "meta": {
#            "expectationId": 741377
#          }
#        },
#        "result": {
#          "observed_value": 0.0,
#          "element_count": 2509,
#          "missing_count": null,
#          "missing_percent": null
#        },
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2025-11-18T12:13:34.000536Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      }
#    ],
#    "evaluation_parameters": {},
#    "statistics": {
#      "evaluated_expectations": 2,
#      "successful_expectations": 2,
#      "unsuccessful_expectations": 0,
#      "success_percent": 100.0
#    },
#    "meta": {
#      "great_expectations_version": "0.18.12",
#      "expectation_suite_name": "weather_expectation_suite",
#      "run_id": {
#        "run_name": null,
#        "run_time": "2025-11-18T13:13:34.536484+01:00"
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "014be698-c478-11f0-8a9d-0a8642b9b879"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
#      "validation_time": "20251118T121334.536318Z",
#      "expectation_suite_meta": {
#        "great_expectations_version": "0.18.12"
#      }
#    }
#  })

# %% [markdown]
# #### Enter a description for each feature in the Feature Group

# %%
weather_fg.update_feature_description("date", "Date of measurement of weather")
weather_fg.update_feature_description("city", "City where weather is measured/forecast for")
weather_fg.update_feature_description("temperature_2m_mean", "Temperature in Celsius")
weather_fg.update_feature_description("precipitation_sum", "Precipitation (rain/snow) in mm")
weather_fg.update_feature_description("wind_speed_10m_max", "Wind speed at 10m above ground")
weather_fg.update_feature_description("wind_direction_10m_dominant", "Dominant Wind direction over the dayd")
