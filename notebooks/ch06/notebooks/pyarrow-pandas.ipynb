# %%
import pandas as pd

df = pd.DataFrame({"a": [1], "b": [3.14], "c": ["MBV"]})
df.dtypes
# Out:
# a      int64
# b    float64
# c     object
# dtype: object

# %%
#pd.options.future.infer_string = True
df_w_pyarrow_backend = df.convert_dtypes(dtype_backend="pyarrow")
df_w_pyarrow_backend.dtypes
# Out:
# a     int64[pyarrow]
# b    double[pyarrow]
# c    string[pyarrow]
# dtype: object

# %% [markdown]
# ### Pandas to Arrow
# ![image.png](attachment:0f3f289e-2234-43ba-8d89-882516d2867f.png)
#
# Reference: https://arrow.apache.org/docs/python/pandas.html

# %% [markdown]
# ### Arrow to Pandas
#
# ![image.png](attachment:9f317fb1-14f9-459b-8c99-e739944a302d.png)

# %%
type(df_w_pyarrow_backend.values)
# Out:
# numpy.ndarray
